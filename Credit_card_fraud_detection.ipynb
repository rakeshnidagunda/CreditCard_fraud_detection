# %% [markdown]
# <a href="https://colab.research.google.com/github/rakeshnidagunda/CreditCard_fraud_detection/blob/main/Credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the dataset to a Pandas DataFrame
ccd=pd.read_csv('/creditcard.csv')

# %%
#printing frist 5 rows of the dataset
ccd.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#due to sensitive data for the customer using PCA the actual value is changed
ccd.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 35737  38240  1.232390  0.122010  0.157352  0.261906  0.158523  0.273022
# 35738  38240  1.114040  0.571203  0.427035  2.442135 -0.020967 -0.501774
# 35739  38241  1.057020  0.007895  0.239256  1.236048  0.032239  0.350868
# 35740  38241 -1.546226  0.693338  1.002815 -1.528992  0.294692 -0.464031
# 35741  38241 -0.231062  0.243033  1.071749 -0.324598 -0.000000       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 35737 -0.143169  0.138664 -0.146805  ... -0.233618 -0.677894  0.052511
# 35738  0.320237 -0.082876 -1.182685  ...  0.028826 -0.032705 -0.056634
# 35739  0.023279  0.137328  0.037981  ... -0.043316 -0.022866 -0.155991
# 35740  0.264880  0.307358  0.022915  ... -0.176713 -0.164637  0.197999
# 35741       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
#dataset information
ccd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35742 entries, 0 to 35741
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    35742 non-null  int64
#  1   V1      35742 non-null  float64
#  2   V2      35742 non-null  float64
#  3   V3      35742 non-null  float64
#  4   V4      35742 non-null  float64
#  5   V5      35742 non-null  float64
#  6   V6      35741 non-null  float64
#  7   V7      35741 non-null  float64
#  8   V8      35741 non-null  float64
#  9   V9      35741 non-null  float64
#  10  V10     35741 non-null  float64
#  11  V11     35741 non-null  float64
#  12  V12     35741 non-null  float64
#  13  V13     35741 non-null  float64
#  14  V14     35741 non-null  float64
#  15  V15     35741 non-null  float64
#  16  V16     35741 non-null  float64
#  17  V17     35741 non-null  float64
#  18  V18     35741 non-null  float64
#  19  V19     35741 non-null  float64
# ...

# %%
#checking the number of missing values in each column
ccd.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
ccd.dropna(inplace=True,axis=0)#droping null value

# %%
ccd.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
ccd['Class'].value_counts()
# Out:
# Class
# 0.0    35638
# 1.0      103
# Name: count, dtype: int64

# %%
ccd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35741 entries, 0 to 35740
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    35741 non-null  int64
#  1   V1      35741 non-null  float64
#  2   V2      35741 non-null  float64
#  3   V3      35741 non-null  float64
#  4   V4      35741 non-null  float64
#  5   V5      35741 non-null  float64
#  6   V6      35741 non-null  float64
#  7   V7      35741 non-null  float64
#  8   V8      35741 non-null  float64
#  9   V9      35741 non-null  float64
#  10  V10     35741 non-null  float64
#  11  V11     35741 non-null  float64
#  12  V12     35741 non-null  float64
#  13  V13     35741 non-null  float64
#  14  V14     35741 non-null  float64
#  15  V15     35741 non-null  float64
#  16  V16     35741 non-null  float64
#  17  V17     35741 non-null  float64
#  18  V18     35741 non-null  float64
#  19  V19     35741 non-null  float64
# ...

# %% [markdown]
# This above dataset is highly unbalanced

# %% [markdown]
# *   0--> Normal Transactions
# *   1--> Fraudulant Transactions

# %%
#separating the data for analysis
legit=ccd[ccd.Class==0]
fraud=ccd[ccd.Class==1]

# %%
legit.shape
# Out:
# (35638, 31)

# %%
fraud.shape
# Out:
# (103, 31)

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    35638.000000
# mean        84.185241
# std        227.223359
# min          0.000000
# 25%          7.000000
# 50%         22.000000
# 75%         76.000000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     103.000000
# mean       90.471165
# std       247.173335
# min         0.000000
# 25%         1.000000
# 50%         3.760000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
ccd.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    24007.013890 -0.186593  0.055909   0.752026  0.179227 -0.201556
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.102516 -0.094806  0.021671  0.268769  ...  0.043058 -0.032782
# 1.0   -2.306085 -7.743100  3.867920 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.112858 -0.040645  0.008169  0.135484  0.021354  0.008491  0.003549
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#           Amount
# Class
# 0.0    84.185241
# 1.0    90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# Under sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transaction and Fraudulent transaction

# %% [markdown]
# Number of fraudulent transaction is 103

# %%
legit_sample=legit.sample(n=103)#random sampling

# %% [markdown]
# Concatinating two data frame

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)#row wise concatinate

# %%
new_dataset.head()
# Out:
#         Time         V1         V2        V3        V4        V5        V6  \
# 20266  30913  -1.237553   0.540558  2.155555  0.751208 -0.770681  0.281009
# 15504  26898   1.169554  -0.677216  0.595143 -0.092141 -0.745705  0.586584
# 4128    3745  -0.873846   0.244037  2.005920 -1.767428 -0.131642 -0.548340
# 6812    8592 -23.066842 -25.640527 -3.080313  4.866932  6.901397 -4.074335
# 16749  28111  -1.922669   0.550875  2.451904 -1.579657 -1.195832  1.480662
#
#              V7        V8        V9  ...       V21       V22        V23  \
# 20266 -0.549543 -0.580252  0.700200  ...  0.758159  0.117616  -0.080448
# 15504 -0.826817  0.350524  1.247805  ... -0.251078 -0.659855  -0.094876
# 4128   0.010448  0.058545 -0.243056  ... -0.189932 -0.542487  -0.121148
# 6812   2.027345 -2.688652  3.402966  ... -5.378106  3.312971  13.876221
# 16749 -1.364653 -3.122300  1.252603  ...  2.301580 -1.852286   0.078326
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 30442 -6.805053  2.928356 -4.917130  ...  1.691042  0.920021 -0.151104
# 30473 -7.281328  3.332250 -3.679659  ...  1.550473  0.614573  0.028521
# 30496 -6.311699  3.449167 -5.416284  ...  1.194888 -0.845753  0.190674
# 31002 -6.958679  3.877795 -5.541529  ...  1.128641 -0.962960 -0.110045
# 33276 -5.283435  0.131619  0.658176  ... -0.734308 -0.599926 -4.908301
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    103
# 1.0    103
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()#this step tell us we got good sample or bad sample
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    22389.689320 -0.479128 -0.280479   0.674274  0.330470 -0.307101
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.115619 -0.137942 -0.003873  0.393391  ... -0.166064 -0.072454
# 1.0   -2.306085 -7.743100  3.867920 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.065913  0.115697 -0.079301  0.143928  0.057014  0.035331  0.017978
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#            Amount
# Class
# 0.0    108.824175
# 1.0     90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into features and targets

# %%
X=new_dataset.drop(columns='Class',axis=1)#drop class column
Y=new_dataset['Class']

# %%
Y.head()
# Out:
# 20266    0.0
# 15504    0.0
# 4128     0.0
# 6812     0.0
# 16749    0.0
# Name: Class, dtype: float64

# %% [markdown]
# Split the data into training data and testing data

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,x_train.shape,x_test.shape)
# Out:
# (206, 30) (164, 30) (42, 30)

# %% [markdown]
# Model training

# %% [markdown]
# Logistic regression

# %%
model=LogisticRegression()

# %%
#trianing logistic regression using training data
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model evaulation

# %% [markdown]
# Accuracy score

# %%
#accuracy on training data
x_train_prediction=model.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction,y_train)

# %%
print('Accuracy on Trainig data is:',training_data_accuracy)
# Out:
# Accuracy on Trainig data is: 0.9573170731707317

# %%
#accuracy on test data
x_test_prediction=model.predict(x_test)
test_data_accuracy=accuracy_score(x_test_prediction,y_test)

# %%
print('Accuracy on Testing data is:',test_data_accuracy)
# Out:
# Accuracy on Testing data is: 0.9285714285714286
